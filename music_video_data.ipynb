# %%
import pandas as pd

# %%
import matplotlib
# %matplotlib inline

# %%
path = 'music_video_reaserch.csv'
music_data = pd.read_csv(path)

# %%
music_data
# Out:
#                           时间戳记 What is your name?  \
# 0   2022/11/16 12:21:38 下午 GMT              Rocio
# 1   2022/11/16 12:35:40 下午 GMT                Kat
# 2    2022/11/16 1:14:46 下午 GMT              Tilly
# 3    2022/11/16 1:39:25 下午 GMT            Shi Shi
# 4    2022/11/16 1:42:53 下午 GMT               Jana
# 5    2022/11/16 1:53:24 下午 GMT           Ning Wei
# 6    2022/11/16 2:01:17 下午 GMT               Jade
# 7    2022/11/16 2:06:22 下午 GMT         Zishan liu
# 8    2022/11/16 2:12:40 下午 GMT               Dara
# 9    2022/11/16 2:40:47 下午 GMT                Wen
# 10   2022/11/16 8:26:24 下午 GMT              Adele
# 11   2022/11/17 1:50:57 下午 GMT               Beth
# 12   2022/11/18 4:03:22 下午 GMT           Precious
#
#    What kind of music do you like?  \
# 0                     Pop and rock
# 1                            Indie
# 2                    Soul/r&b/rock
# 3                     Jazz Hip-hop
# 4                             Rock
# 5                         Pop/Jazz
# ...

# %%
music_data.head() #for the first 5 rows, I am afraid I will forget it
# Out:
#                          时间戳记 What is your name?  \
# 0  2022/11/16 12:21:38 下午 GMT              Rocio
# 1  2022/11/16 12:35:40 下午 GMT                Kat
# 2   2022/11/16 1:14:46 下午 GMT              Tilly
# 3   2022/11/16 1:39:25 下午 GMT            Shi Shi
# 4   2022/11/16 1:42:53 下午 GMT               Jana
#
#   What kind of music do you like?  \
# 0                    Pop and rock
# 1                           Indie
# 2                   Soul/r&b/rock
# 3                    Jazz Hip-hop
# 4                            Rock
#
#                       Who is your favourite singer?  \
# 0                                         Manneskin
# 1                                     Rachael Price
# 2  It changes a lot but at the moment rina sawayama
# 3                                              HYBS
# 4                                        John Mayer
#
#   Could you please recommend a MV you like most? (name)  \
# 0                     Bury a friend by Billie Eilish
# ...

# %%
popular_genre = music_data['What kind of music do you like?']
popular_genre
# Out:
# 0                Pop and rock
# 1                       Indie
# 2               Soul/r&b/rock
# 3                Jazz Hip-hop
# 4                        Rock
# 5                    Pop/Jazz
# 6                  Electronic
# 7                         POP
# 8                   Afrobeats
# 9                       Indie
# 10    Afrobeats,  jazz, & pop
# 11                      Metal
# 12                      r n b
# Name: What kind of music do you like?, dtype: object

# %%
popular_genre.unique()
# Out:
# array(['Pop and rock', 'Indie', 'Soul/r&b/rock', 'Jazz Hip-hop', 'Rock',
#        'Pop/Jazz', 'Electronic', 'POP', 'Afrobeats',
#        'Afrobeats,  jazz, & pop', 'Metal', 'r n b'], dtype=object)

# %%
from collections import Counter
most_popular = Counter(popular_genre).most_common(1)
print(most_popular)
# Out:
# [('Indie', 2)]

# %%
music_data.loc[music_data ['What kind of music do you like?'] == 'Indie']
# Out:
#                          时间戳记 What is your name?  \
# 1  2022/11/16 12:35:40 下午 GMT                Kat
# 9   2022/11/16 2:40:47 下午 GMT                Wen
#
#   What kind of music do you like? Who is your favourite singer?  \
# 1                           Indie                 Rachael Price
# 9                           Indie                     Sigur Ros
#
#   Could you please recommend a MV you like most? (name)  \
# 1            Elderbrook - Inner Light with Bob Moses
# 9                             OK Go - The One Moment
#
#   For a MV, which part do you think is the most important?
# 1                           beautiful song and dance
# 9                          the story;special effects

# %%
music_data.loc[music_data ['What is your name?'] == 'Shi Shi']
# Out:
#                         时间戳记 What is your name?  \
# 3  2022/11/16 1:39:25 下午 GMT            Shi Shi
#
#   What kind of music do you like? Who is your favourite singer?  \
# 3                    Jazz Hip-hop                          HYBS
#
#   Could you please recommend a MV you like most? (name)  \
# 3                                  The Glimpse of us
#
#   For a MV, which part do you think is the most important?
# 3                                          the story

# %%
music_data.loc[music_data ['What is your name?'] == 'Kat']
# Out:
#                          时间戳记 What is your name?  \
# 1  2022/11/16 12:35:40 下午 GMT                Kat
#
#   What kind of music do you like? Who is your favourite singer?  \
# 1                           Indie                 Rachael Price
#
#   Could you please recommend a MV you like most? (name)  \
# 1            Elderbrook - Inner Light with Bob Moses
#
#   For a MV, which part do you think is the most important?
# 1                           beautiful song and dance

# %%
popular_reason = music_data['For a MV, which part do you think is the most important?']
popular_reason
# Out:
# 0                              the story
# 1               beautiful song and dance
# 2               beautiful song and dance
# 3                              the story
# 4                        special effects
# 5               beautiful song and dance
# 6               beautiful song and dance
# 7     the story;beautiful song and dance
# 8                              the story
# 9              the story;special effects
# 10                             the story
# 11                             the story
# 12                       special effects
# Name: For a MV, which part do you think is the most important?, dtype: object

# %%
from collections import Counter
most_popular_reason = Counter(popular_reason).most_common(1)
print(most_popular_reason)
# Out:
# [('the story', 5)]

# %%
music_data.loc[music_data ['For a MV, which part do you think is the most important?'] == 'the story']
# Out:
#                           时间戳记 What is your name?  \
# 0   2022/11/16 12:21:38 下午 GMT              Rocio
# 3    2022/11/16 1:39:25 下午 GMT            Shi Shi
# 8    2022/11/16 2:12:40 下午 GMT               Dara
# 10   2022/11/16 8:26:24 下午 GMT              Adele
# 11   2022/11/17 1:50:57 下午 GMT               Beth
#
#    What kind of music do you like? Who is your favourite singer?  \
# 0                     Pop and rock                     Manneskin
# 3                     Jazz Hip-hop                          HYBS
# 8                        Afrobeats                        Wizkid
# 10         Afrobeats,  jazz, & pop                 Mary J Blige
# 11                           Metal                   Fiona Apple
#
#    Could you please recommend a MV you like most? (name)  \
# 0                      Bury a friend by Billie Eilish
# 3                                   The Glimpse of us
# 8                                    Calm Down - Rema
# ...
